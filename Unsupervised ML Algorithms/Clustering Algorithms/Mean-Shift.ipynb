# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import MeanShift, estimate_bandwidth

# %%
# Step 1: Generate Synthetic Data
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=42)

# %%
# Step 2: Estimate Bandwidth
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)
print(f"Estimated Bandwidth: {bandwidth}")
# Out:
# Estimated Bandwidth: 1.415100384475083

# %%
# Step 3: Apply Mean-Shift Clustering
mean_shift = MeanShift(bandwidth=bandwidth, bin_seeding=True)
mean_shift.fit(X)
labels = mean_shift.labels_
cluster_centers = mean_shift.cluster_centers_

# %%
# Step 4: Plot Results
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30, alpha=0.7, label='Data Points')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], 
            c='red', marker='X', s=200, label='Cluster Centers')
plt.title('Mean-Shift Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
